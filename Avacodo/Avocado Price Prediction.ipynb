# %% [markdown]
# # Avocado Price Prediction

# %%
# Import packages for the predictions
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('avocado.csv', index_col='Date') # df stand for dataframe.
# Also it is a common convention to call this df
# .head() is used first five rows
df.head()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046       4225  \
# Date
# 2015-12-27           0          1.33      64236.62  1036.74   54454.85
# 2015-12-20           1          1.35      54876.98   674.28   44638.81
# 2015-12-13           2          0.93     118220.22   794.70  109149.67
# 2015-12-06           3          1.08      78992.15  1132.00   71976.41
# 2015-11-29           4          1.28      51039.60   941.48   43838.39
#
#               4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-12-27   48.16     8696.87     8603.62       93.25          0.0
# 2015-12-20   58.33     9505.56     9408.07       97.49          0.0
# 2015-12-13  130.50     8145.35     8042.21      103.14          0.0
# 2015-12-06   72.58     5811.16     5677.40      133.76          0.0
# 2015-11-29   75.78     6183.95     5986.26      197.69          0.0
#
#                     type  year  region
# Date
# 2015-12-27  conventional  2015  Albany
# 2015-12-20  conventional  2015  Albany
# 2015-12-13  conventional  2015  Albany
# 2015-12-06  conventional  2015  Albany
# 2015-11-29  conventional  2015  Albany

# %%
df.drop(labels=['Unnamed: 0'],axis=1)
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...                  ...           ...      ...        ...     ...
# 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27     8696.87     8603.62       93.25          0.0  conventional
# 2015-12-20     9505.56     9408.07       97.49          0.0  conventional
# 2015-12-13     8145.35     8042.21      103.14          0.0  conventional
# 2015-12-06     5811.16     5677.40      133.76          0.0  conventional
# 2015-11-29     6183.95     5986.26      197.69          0.0  conventional
# ...                ...         ...         ...          ...           ...
# 2018-02-04    13498.67    13066.82      431.85          0.0       organic
# 2018-01-28     9264.84     8940.04      324.80          0.0       organic
# 2018-01-21     9394.11     9351.80       42.31          0.0       organic
# 2018-01-14    10969.54    10919.54       50.00          0.0       organic
# 2018-01-07    12014.15    11988.14       26.01          0.0       organic
#
#             year            region
# Date
# 2015-12-27  2015            Albany
# 2015-12-20  2015            Albany
# 2015-12-13  2015            Albany
# 2015-12-06  2015            Albany
# 2015-11-29  2015            Albany
# ...          ...               ...
# 2018-02-04  2018  WestTexNewMexico
# 2018-01-28  2018  WestTexNewMexico
# 2018-01-21  2018  WestTexNewMexico
# 2018-01-14  2018  WestTexNewMexico
# 2018-01-07  2018  WestTexNewMexico
#
# [18249 rows x 12 columns]

# %%
df.rename(columns={
    'Date':'Date',
    'AveragePrice':'Average_Price',
    'Total Volume':'Total_Volume',
    '4046':'PLU_4046_sold',
    '4225':'PLU_4225_sold',
    '4770':'PLU_4770_sold',
    'Total Bags':'Total_Bags',
    'Small Bags':'Small_Bags',
    'Large Bags':'Large_Bags',
    'XLarge Bags':'XLarge_Bags',
    'type':'Type',
    'year':'Year',
    'region':'Region',
})
# Out:
#             Unnamed: 0  Average_Price  Total_Volume  PLU_4046_sold  \
# Date
# 2015-12-27           0           1.33      64236.62        1036.74
# 2015-12-20           1           1.35      54876.98         674.28
# 2015-12-13           2           0.93     118220.22         794.70
# 2015-12-06           3           1.08      78992.15        1132.00
# 2015-11-29           4           1.28      51039.60         941.48
# ...                ...            ...           ...            ...
# 2018-02-04           7           1.63      17074.83        2046.96
# 2018-01-28           8           1.71      13888.04        1191.70
# 2018-01-21           9           1.87      13766.76        1191.92
# 2018-01-14          10           1.93      16205.22        1527.63
# 2018-01-07          11           1.62      17489.58        2894.77
#
#             PLU_4225_sold  PLU_4770_sold  Total_Bags  Small_Bags  Large_Bags  \
# Date
# 2015-12-27       54454.85          48.16     8696.87     8603.62       93.25
# 2015-12-20       44638.81          58.33     9505.56     9408.07       97.49
# 2015-12-13      109149.67         130.50     8145.35     8042.21      103.14
# 2015-12-06       71976.41          72.58     5811.16     5677.40      133.76
# 2015-11-29       43838.39          75.78     6183.95     5986.26      197.69
# ...                   ...            ...         ...         ...         ...
# 2018-02-04        1529.20           0.00    13498.67    13066.82      431.85
# 2018-01-28        3431.50           0.00     9264.84     8940.04      324.80
# 2018-01-21        2452.79         727.94     9394.11     9351.80       42.31
# 2018-01-14        2981.04         727.01    10969.54    10919.54       50.00
# 2018-01-07        2356.13         224.53    12014.15    11988.14       26.01
#
#             XLarge_Bags          Type  Year            Region
# Date
# 2015-12-27          0.0  conventional  2015            Albany
# 2015-12-20          0.0  conventional  2015            Albany
# 2015-12-13          0.0  conventional  2015            Albany
# 2015-12-06          0.0  conventional  2015            Albany
# 2015-11-29          0.0  conventional  2015            Albany
# ...                 ...           ...   ...               ...
# 2018-02-04          0.0       organic  2018  WestTexNewMexico
# 2018-01-28          0.0       organic  2018  WestTexNewMexico
# 2018-01-21          0.0       organic  2018  WestTexNewMexico
# 2018-01-14          0.0       organic  2018  WestTexNewMexico
# 2018-01-07          0.0       organic  2018  WestTexNewMexico
#
# [18249 rows x 13 columns]

# %%
# .tail() is used last five rows
df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046     4225    4770  \
# Date
# 2018-02-04           7          1.63      17074.83  2046.96  1529.20    0.00
# 2018-01-28           8          1.71      13888.04  1191.70  3431.50    0.00
# 2018-01-21           9          1.87      13766.76  1191.92  2452.79  727.94
# 2018-01-14          10          1.93      16205.22  1527.63  2981.04  727.01
# 2018-01-07          11          1.62      17489.58  2894.77  2356.13  224.53
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# Date
# 2018-02-04    13498.67    13066.82      431.85          0.0  organic  2018
# 2018-01-28     9264.84     8940.04      324.80          0.0  organic  2018
# 2018-01-21     9394.11     9351.80       42.31          0.0  organic  2018
# 2018-01-14    10969.54    10919.54       50.00          0.0  organic  2018
# 2018-01-07    12014.15    11988.14       26.01          0.0  organic  2018
#
#                       region
# Date
# 2018-02-04  WestTexNewMexico
# 2018-01-28  WestTexNewMexico
# 2018-01-21  WestTexNewMexico
# 2018-01-14  WestTexNewMexico
# 2018-01-07  WestTexNewMexico

# %%
# Shows the first five rows of AveragePrice column in df
# df.AveragePrice.head() also shows same value
df['Average_Price'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Average_Price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-d4cd804c0466> in <module>
#       1 # Shows the first five rows of AveragePrice column in df
#       2 # df.AveragePrice.head() also shows same value
# ----> 3 df['Average_Price'].head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Average_Price'

# %%
df['Region'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-8262035a849e> in <module>
# ----> 1 df['Region'].unique()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Region'

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
Region =df["region"].unique().tolist()
Region
# Out:
# ['Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico']

# %%
def Plot_Time_Series(x):
    x=df[[]]
    plt.figure(figsize=(8,8))
    x['Average_Price'].plot()
    plt.title(x)
    plt.xlabel('Date')
    plt.ylabel('Average Price')
    plt.show()

# %%
# Albany
x=Region[0]
Plot_Time_Series(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f7406afe4259> in <module>
#       1 # Albany
#       2 x=Region[0]
# ----> 3 Plot_Time_Series(x)
#
# <ipython-input-15-fb2aaaaa97e5> in Plot_Time_Series(x)
#       1 def Plot_Time_Series(x):
#       2     plt.figure(figsize=(8,8))
# ----> 3     x['Average_Price'].plot()
#       4     plt.title(x)
#       5     plt.xlabel('Date')
#
# TypeError: string indices must be integers

# %%
x=Region[1]
Plot_Time_Series(x)

# %%
x=Region[2]
Plot_Time_Series(x)

# %%
x=Region[3]
Plot_Time_Series(x)

# %%
x=Region[4]
Plot_Time_Series(x)

# %%
x=Region[5]
Plot_Time_Series(x)

# %%
x=Region[6]
Plot_Time_Series(x)

# %%
x=Region[7]
Plot_Time_Series(x)

# %%
x=Region[8]
Plot_Time_Series(x)

# %%
x=Region[9]
Plot_Time_Series(x)

# %%
x=Region[10]
Plot_Time_Series(x)

# %%
x=Region[11]
Plot_Time_Series(x)

# %%
x=Region[12]
Plot_Time_Series(x)

# %%
x=Region[13]
Plot_Time_Series(x)

# %%
x=Region[14]
Plot_Time_Series(x)

# %%
x=Region[15]
Plot_Time_Series(x)

# %%
x=Region[16]
Plot_Time_Series(x)

# %%
x=Region[17]
Plot_Time_Series(x)

# %%
x=Region[18]
Plot_Time_Series(x)

# %%
x=Region[19]
Plot_Time_Series(x)

# %%
x=Region[20]
Plot_Time_Series(x)

# %%
x=Region[21]
Plot_Time_Series(x)

# %%
x=Region[22]
Plot_Time_Series(x)

# %%
x=Region[23]
Plot_Time_Series(x)

# %%
x=Region[24]
Plot_Time_Series(x)

# %%
x=Region[25]
Plot_Time_Series(x)

# %%
x=Region[26]
Plot_Time_Series(x)

# %%
x=Region[27]
Plot_Time_Series(x)

# %%
x=Region[28]
Plot_Time_Series(x)

# %%
x=Region[29]
Plot_Time_Series(x)

# %%
x=Region[30]
Plot_Time_Series(x)
